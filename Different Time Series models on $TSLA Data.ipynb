# %% [markdown]
# # Performing Different Time Series Models on $TSLA data
#
# * __Author:__ Kiran Kaushal Kopalley
# * __Date:__ 3/1/2024

# %%
import pandas_datareader.data as pdr
import pandas as pd
from datetime import datetime
import yfinance as fyf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fyf.pdr_override()
df_tesla = pdr.get_data_yahoo('TSLA')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df_tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2024-02-26  192.289993  201.779999  192.000000  199.399994  199.399994
# 2024-02-27  204.039993  205.600006  198.259995  199.729996  199.729996
# 2024-02-28  200.419998  205.300003  198.440002  202.039993  202.039993
# 2024-02-29  204.179993  205.279999  198.449997  201.880005  201.880005
# 2024-03-01  200.520004  204.520004  198.500000  202.639999  202.639999
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# ...

# %% [markdown]
# ## Simple Moving Average

# %%
df_tesla['Open'].plot(figsize=(20,9))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open: 10 days rolling'] = df_tesla['Open'].rolling(window=10, min_periods=1).mean()

# %%
df_tesla[['Open','Open: 10 days rolling']].plot(xlim=['2020-01-01','2024-02-29'],figsize=(25,11))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['Open: 30 days rolling'] = df_tesla['Open'].rolling(window=30, min_periods=1).mean()

# %%
df_tesla['Open: 50 days rolling'] = df_tesla['Open'].rolling(window=50, min_periods=1).mean()

# %%
df_tesla[['Open','Open: 10 days rolling','Open: 30 days rolling','Open: 50 days rolling']].plot(xlim=['2021-01-01','2024-02-29'],figsize=(25,11))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# __Disadvantages of Simple Moving Average:__
# * Similar importance is given to all the data. for any window the equal weights are applied and the averages are computed making it inaccurate. (x1+x2+x3+---------+xn)/n
# * So that is the reason we use **"Exponential Weighted Moving Average".**
#
# Before learning about EWMA we will have to learn about __Cummulative Moving Average__.

# %% [markdown]
# ### Cummulative Moving Average

# %%
df_tesla['Open'].expanding().mean().plot(figsize=(20,15))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Exponential Moving Average
#
# *EMA(t) = a * (x(t)) + (1-a) * EMA(t-1)*
#
# where a is the weight
#
# This is used to prevent any lags.

# %%
#EMA
df_tesla['EMA_0.1'] = df_tesla['Open'].ewm(alpha=0.1, adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.1']].plot(xlim=['2020-01-01','2024-02-29'],figsize=(25,11))
# Out:
# <Axes: xlabel='Date'>

# %%
df_tesla['EMA_0.3'] = df_tesla['Open'].ewm(alpha=0.3, adjust=False).mean()

# %%
df_tesla[['Open','EMA_0.3']].plot(xlim=['2023-01-01','2024-02-29'],figsize=(25,11))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Exponential Weighted Moving Average

# %%
df_tesla['EWMA_0.1'] = df_tesla['Open'].ewm(span=5, adjust=False).mean()

# %%
df_tesla[['Open','EWMA_0.1']]
